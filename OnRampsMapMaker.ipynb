# %%
# imports
import pandas as pd
import numpy as np
import folium as fm

# %% [markdown]
# ## Load Data

# %%
#upload the OnRampsFinal.csv file or equivalent
#change the path to your path
path = '/content/OnRampsFinal.csv'
df = pd.read_csv(path)

# %% [markdown]
# ## Visualization

# %% [markdown]
# #### Create the map of Texas

# %%
#create a map of Texas
texas_map = fm.Map(location=[31.9686, -99.9018], zoom_start=6)
texas_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_150534cd7e324a6c337c66f7e95592c2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_150534cd7e324a6c337c66f7e95592c2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_150534cd7e324a6c337c66f7e95592c2 = L.map(
#                 &quot;map_150534cd7e324a6c337c66f7e95592c2&quot;,
#                 {
#                     center: [31.9686, -99.9018],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b8073b5563ad0b04d0947c157d69aab2 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_150534cd7e324a6c337c66f7e95592c2);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### Create icons for the schools

# %%
# create a feature for the school data
schools = fm.map.FeatureGroup()

# %%
# combine the district and the campus into one string
labels = list(zip(df.Campus.tolist(), df.District.tolist()))

# %%
import geopandas as gpd
from shapely.geometry import Point
geometry = [Point(xy) for xy in zip(df['X'], df['Y'])]
gdf = gpd.GeoDataFrame(df, geometry=geometry, crs="EPSG:4326")

# %%
#create map and add features
texas_map = fm.Map(location=[31.9686, -99.9018], zoom_start=6)

fm.GeoJson(
    gdf,
    name="OnRamps High School Map",
    zoom_on_click=True,
    marker=fm.Marker(icon=fm.Icon(icon='star', color='orange')),
    tooltip=fm.GeoJsonTooltip(fields=["Campus", "District"]),
    popup=fm.GeoJsonPopup(fields=["Campus", "District", "Address"]),
).add_to(texas_map)

texas_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7af8ef0070b3317f442525d20a40a693 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumpopup {
#                             margin: auto;
#                         }
#                        .foliumpopup table{
#                             margin: auto;
#                         }
#                         .foliumpopup tr{
#                             text-align: left;
#                         }
#                         .foliumpopup th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7af8ef0070b3317f442525d20a40a693&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7af8ef0070b3317f442525d20a40a693 = L.map(
#                 &quot;map_7af8ef0070b3317f442525d20a40a693&quot;,
#                 {
#                     center: [31.9686, -99.9018],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d596d239ad7b49a856271a617f1e6ac7 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_7af8ef0070b3317f442525d20a40a693);
#
#
#         function geo_json_03ee596f76a0d8e80ef0847cfbfb948e_pointToLayer(feature, latlng) {
#             var opts = {};
#
#             const iconOptions = {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             const iconRootAlias = L.AwesomeMarkers
#             opts.icon = new iconRootAlias.Icon(iconOptions)
#
#             return new L.Marker(latlng, opts)
#         }
#
#         function geo_json_03ee596f76a0d8e80ef0847cfbfb948e_onEachFeature(feature, layer) {
#             layer.on({
#                 click: function(e) {
#                     if (typeof e.target.getBounds === &#x27;function&#x27;) {
#                         map_7af8ef0070b3317f442525d20a40a693.fitBounds(e.target.getBounds());
#                     }
#                     else if (typeof e.target.getLatLng === &#x27;function&#x27;){
#                         let zoom = map_7af8ef0070b3317f442525d20a40a693.getZoom()
#                         zoom = zoom &gt; 12 ? zoom : zoom + 1
#                         map_7af8ef0070b3317f442525d20a40a693.flyTo(e.target.getLatLng(), zoom)
#                     }
#                 }
#             });
#         };
#         var geo_json_03ee596f76a0d8e80ef0847cfbfb948e = L.geoJson(null, {
#                 onEachFeature: geo_json_03ee596f76a0d8e80ef0847cfbfb948e_onEachFeature,
#
#                 pointToLayer: geo_json_03ee596f76a0d8e80ef0847cfbfb948e_pointToLayer
#         });
#
#         function geo_json_03ee596f76a0d8e80ef0847cfbfb948e_add (data) {
#             geo_json_03ee596f76a0d8e80ef0847cfbfb948e
#                 .addData(data)
#                 .addTo(map_7af8ef0070b3317f442525d20a40a693);
#         }
#             geo_json_03ee596f76a0d8e80ef0847cfbfb948e_add({&quot;bbox&quot;: [-106.5737841, 25.8920001, -94.0053228, 35.3521063], &quot;features&quot;: [{&quot;bbox&quot;: [-95.4081344, 29.91671119999999, -95.4081344, 29.91671119999999], &quot;geometry&quot;: {&quot;coordinates&quot;: [-95.4081344, 29.91671119999999], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;Address&quot;: &quot;11101 Airline Dr, Houston, TX 77037, USA&quot;, &quot;Campus&quot;: &quot;Aldine High School&quot;, &quot;District&quot;: &quot;Aldine ISD&quot;, &quot;Unnamed: 0&quot;: 0, &quot;X&quot;: -95.4081344, &quot;Y&quot;: 29.91671119999999, &quot;cord&quot;: &quot;(29.91671119999999, -95.4081344)&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-95.4201587, 29.9147724, -95.4201587, 29.9147724], &quot;geometry&quot;: {&quot;coordinates&quot;: [-95.4201587, 29.9147724], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;1&quot;, &quot;properties&quot;: {&quot;Address&quot;: &quot;311 West Road, Houston, TX 77038, USA&quot;, &quot;Campus&quot;: &quot;Blanson CTE High School&quot;, &quot;District&quot;: &quot;Aldine ISD&quot;, &quot;

# %%
# Save the map to html
texas_map.save('OnRamps_Full_Map.html')

# %% [markdown]
# ## **Extra:** Clustering by Distance

# %%
# Other imports
from sklearn.cluster import DBSCAN
from sklearn.metrics.pairwise import haversine_distances
from math import radians
import numpy as np

# %%
# Function to calculate Haversine distance between two points
def haversine(point1, point2):
    # Convert latitude and longitude from degrees to radians
    point1_rad = [radians(coord) for coord in point1]
    point2_rad = [radians(coord) for coord in point2]

    # Calculate haversine distance
    distance = haversine_distances([point1_rad, point2_rad])[0][1]

    # Multiply by Earth radius to get distance in kilometers
    distance_km = distance * 6371000 / 1000  # convert meters to kilometers

    return distance_km

# %%
# implement a distance based clustering method that takes into account the
# earths curvature

epsilon = 10  # max distance between two samples(kilometers)
min_samples = 2  # min number of samples required to form a cluster
dbscan = DBSCAN(eps=epsilon, min_samples=min_samples, metric=haversine)

# %%
# cluster our data and add result to dataframe
cluster = dbscan.fit_predict(gdf[['X', 'Y']].values.tolist())
gdf['Cluster'] = cluster

# %%
# grab unique colors(currently there are only up to 19 colors - minus grey)
colors = ['lightblue', 'cadetblue', 'darkred', 'pink', 'beige',  'darkgreen',
          'lightred', 'lightgreen', 'darkpurple', 'purple', 'blue', 'red',
          'darkblue', 'orange', 'green', 'white', 'black', 'lightgray']
# map each unique cluster to a color
clust = gdf['Cluster'].drop_duplicates().tolist()
# we want the non clustered colors to be consistent so we temporarily remove -1
if -1 in clust:
  clust.remove(-1)
value_color_dict = dict(zip(clust, colors[:len(clust)]))
# add back -1 and assign it to be grey
value_color_dict[-1] = 'gray'

# %%
texas_map = fm.Map(location=[31.0000, -100.0000], zoom_start=6)

# Add markers for each point in the GeoDataFrame with color based on 'Cluster'
for index, row in gdf.iterrows():
    c = value_color_dict.get(row['Cluster'], 'grey')  # Default color is 'green' if not found in dictionary
    fm.Marker(
        location=[row['Y'], row['X']],
        icon=fm.Icon(color=c),
        popup=f'<b>Campus:</b> {row["Campus"]}<br><b>District:</b> {row["District"]}<br><b>Address:</b> {row["Address"]}',
        tooltip=f'<b>Campus:</b> {row["Campus"]}<br><b>District:</b> {row["District"]}'
    ).add_to(texas_map)
texas_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fbc6a26cff7d4c49021a2ae522543af1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fbc6a26cff7d4c49021a2ae522543af1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fbc6a26cff7d4c49021a2ae522543af1 = L.map(
#                 &quot;map_fbc6a26cff7d4c49021a2ae522543af1&quot;,
#                 {
#                     center: [31.0, -100.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_24c9c781d8a8c11eb6104d27e1afdfce = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_fbc6a26cff7d4c49021a2ae522543af1);
#
#
#             var marker_2c771c2e7243307befe372e2c6e32fd2 = L.marker(
#                 [29.91671119999999, -95.4081344],
#                 {}
#             ).addTo(map_fbc6a26cff7d4c49021a2ae522543af1);
#
#
#             var icon_99e0d37709af4f71a49990db8d831cd1 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;lightblue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_2c771c2e7243307befe372e2c6e32fd2.setIcon(icon_99e0d37709af4f71a49990db8d831cd1);
#
#
#         var popup_c815b345faf37693ae1882fa331a7aba = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ce72dc7e1a9d6e6e4f2503ec4277e02e = $(`&lt;div id=&quot;html_ce72dc7e1a9d6e6e4f2503ec4277e02e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Campus:&lt;/b&gt; Aldine High School&lt;br&gt;&lt;b&gt;District:&lt;/b&gt; Aldine ISD&lt;br&gt;&lt;b&gt;Address:&lt;/b&gt; 11101 Airline Dr, Houston, TX 77037, USA&lt;/div&gt;`)[0];
#                 popup_c815b345faf37693ae1882fa331a7aba.setContent(html_ce72dc7e1a9d6e6e4f2503ec4277e02e);
#
#
#
#         marker_2c771c2e7243307befe372e2c6e32fd2.bindPopup(popup_c815b345faf37693ae1882fa331a7aba)
#         ;
#
#
#
#
#             marker_2c771c2e7243307befe372e2c6e32fd2.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;b&gt;Campus:&lt;/b&gt; Aldine High School&lt;br&gt;&lt;b&gt;District:&lt;/b&gt; Aldine ISD
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_f17d5588ebf49de63102ac33469411cd = L.marker(
#                 [29.9147724, -95.4201587],
#                 {}
#             ).addTo(map_fbc6a26cff7d4c49021a2ae522543af1);
#
#
#             var icon_dafbc0b0cb7ae8232a024d4ac2b87da3 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;lightblue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_f17d5588ebf49de63102ac33469411cd.setIcon(icon_dafbc0b0cb7ae8232a024d4ac2b87da3);
#
#
#         var popup_4b5da42d9afac565b070bbfcc3e02e2c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_96f39d8cfe603e4dda5ac041f4167e15 = $(`&lt;div id=&quot;html_96f39d8cfe603e4dda5ac041f4167e15&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Campus:&lt;/b&gt; Blanson CTE High School&lt;br&gt;&lt;b&gt;District:&lt;/b&gt; Aldine ISD&lt;br&gt;&lt;b&gt;Address:&lt;/b&gt; 311 West Road, Houston, TX 77038, USA&lt;/div&gt;`)[0];
#                 popup_4b5da42d9afac565b070bbfcc3e02e2c.setContent(html_96f39d8cfe603e4dda5ac041f4167e15);
#
#
#
#         marker_f17d5588ebf49de63102ac33469411cd.bindPopup(popup_4b5da42d9afac565b070bbfcc3e02e2c)
#         ;
#
#
#
#
#             marker_f17d5588ebf49de63102ac33469411cd.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;b&gt;Campus:&lt;/b&gt; Blanson CTE High School&lt;br&gt;&lt;b&gt;District:&lt;/b&gt; Aldine ISD
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_2ff09c7651c3231319e4a772bfe6ca2f = L.marker(
#                 [29.8715305, -95.4442853],
#                 {}
#             ).addTo(map_fbc6a26cff7d4c49021a2ae522543af1);
#
#
#             var icon_9d66b5636f163e92161739315be08a2f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;lightblue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_2ff09c7651c3231319e4a772bfe6ca2f.setIcon(icon_9d66b5636f163e92161739315be08a2f);

# %%
texas_map.save('OnRamps_full_clustered_map.html')
